# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from tensorflow.keras.preprocessing.image import load_img,img_to_array,ImageDataGenerator
from tensorflow.keras.applications.imagenet_utils import preprocess_input

# %%
sample_img_path="..//Dataset/Train/Bedroom/00000009.jpg"

# %%
# show test image
sample_img=mpimg.imread(sample_img_path)
plt.imshow(sample_img)

# %%
#create batch of single image
def create_img_batch():
    sample_img_for_augmenetation=load_img(sample_img_path)
    sample_img_for_augmenetation=img_to_array(sample_img)
    samples=np.expand_dims(sample_img,0)
    return samples

# %%
datagen=ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.05,
    height_shift_range=0.1,
    brightness_range=[0.7,1],
    shear_range=10.0,
    zoom_range=[0.5,1.5],
    channel_shift_range=80.0,
    fill_mode="nearest",
    cval=0.0,
    horizontal_flip=True,
    vertical_flip=False,
    rescale=None,
    preprocessing_function=None,
    data_format=None,
    validation_split=0.0,
    dtype=None,
)

# %%
def generate_plots(samples,data_generator):
    plt.figure(figsize=(15,15))
    it=data_generator.flow(samples,batch_size=1)
    for i in range(16):
        plt.subplot(4,4,i+1)
        batch=it.next()
#         print(batch)
        image=batch[0].astype('uint8')
        plt.imshow(image)

# %%
generate_plots(create_img_batch(),datagen)
